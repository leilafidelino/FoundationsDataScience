# %% [markdown]
# # Assignment 1 - Intro to Python

# %% [markdown]
# ### Medium complexity - Birthday Paradox

# %% [markdown]
# Birthday paradox concerns the probability that, in a set of `n` randomly chosen people, some pair of them will have the same birthday. You can read about this problem at https://en.wikipedia.org/wiki/Birthday_problem.
#
# Write a function called **`has_duplicates()`**, that takes a list and returns `True` if there is any element that appears more than once. It should not modify the original list.
#
# If there are 45 students in the class, what are the chances that any two students will have the same birthday? You can estimate this probability by generating random samples of 45 birthdays and checking for matches.
#
# **Hints:**
# 1. you can generate random birthdays with the `randint` function in the `random` module.
# 2. For simplicity, use the day number of the year, not the actual date
# 3. you can use the book solution as a starting point for this assignment: https://github.com/AllenDowney/ThinkPython2/blob/master/code/birthday.py or http://greenteapress.com/thinkpython2/code/birthday.py
#
# The code should print out:
# - number of students
# - number of iterations/samples
# - list of duplicate days for each iteration, where duplicates are found
# - probability

# %%
from random import randint


def has_duplicates(list_bdays):
    '''(list of int) -> bool
    
    Takes a list and returns True if there is any element that appears more than once. It does not modify the original list.'''
    
    copy_list = list_bdays[:]
    copy_list.sort()

    same_day =[]
    duplicate = False
    
    for i in range(len(copy_list)-1):
        if copy_list[i] == copy_list[i+1]:
            same_day.append(copy_list[i])
            duplicate = True
    
    # Removes duplicates in the same_day list.
    global same_day_final
    same_day_final = []
    [same_day_final.append(day) for day in same_day if day not in same_day_final]
        
    return duplicate


def count_matches(num_students, num_iterations):
    ''' (int, int) -> int
    
    Generates a sample of birthdays and counts duplicates.

    num_students: how many students in the group
    num_iterations: how many groups to simulate '''
    
    count = 0
    global iterations_with_duplicates
    iterations_with_duplicates = {}
    
    for i in range(num_iterations) :
        list_bdays = [randint(1, 365) for i in range(num_students)]
        if has_duplicates(list_bdays):
            count += 1
            iterations_with_duplicates[i + 1] = same_day_final
            
            
    return count


def bday_paradox():
    """Runs the birthday simulation and prints the number of matches."""
    num_students = 45
    num_iterations = 1000
    count = count_matches(num_students, num_iterations)
    p = count/num_iterations

    print('Number of students:', num_students )
    print('Number of iterations:', num_iterations)
    print('Probability of at least one match:', p*100, '%')
    print('Iterations with duplicates and their corresponding duplicate day(s): \n', iterations_with_duplicates)
    
    
bday_paradox()
# Out:
# Number of students: 45
# Number of iterations: 1000
# Probability of at least one match: 93.8 %
# Iterations with duplicates and their corresponding duplicate day(s):
#  {1: [12, 152, 169], 2: [34, 182, 273, 302, 359], 3: [64], 4: [129, 226, 357], 5: [31, 212, 327], 6: [113, 247, 313], 7: [100], 8: [128, 136], 9: [150], 10: [63, 91, 176], 11: [311], 12: [59, 115, 353], 13: [10, 146, 169], 14: [64, 216], 15: [197, 266, 273, 326, 345], 16: [203, 343, 364], 17: [286], 18: [309, 312], 19: [121, 145, 163, 172, 260, 304, 326], 20: [109, 278, 315], 21: [45, 185, 320], 22: [43, 170, 299], 23: [57, 74, 80], 24: [166, 204, 241, 245], 25: [54, 89, 231, 329], 26: [3, 321], 27: [129, 240, 241], 28: [218], 29: [126, 157], 30: [66, 133], 31: [4, 189, 305], 32: [70, 91, 108], 33: [235, 337], 34: [97, 221, 355], 35: [124], 36: [81, 150, 211, 216, 234], 37: [273], 38: [174, 205, 316, 333], 39: [24], 40: [120, 225, 296, 325], 41: [167, 225, 290, 308], 42: [167, 231, 355], 43: [14, 34, 93, 299], 44: [184, 307, 356], 45: [20, 211], 46: [3, 77], 47: [103, 147], 48: [64, 279], 49: [61, 95], 50: [58], 51: [16, 36, 273], 52: [291, 314, 320], 53: [247], 54: [20, 142, 154, 333], 55: [51, 75, 82, 141, 174, 340, 359], 56: [6, 254, 258, 326], 57: [264, 312, 323], 58: [21, 261, 297], 59: [135, 179, 352, 364], 60: [65, 285], 61: [160, 277], 62: [286], 63: [101, 108], 64: [164, 284, 342], 65: [98, 224], 66: [3, 56, 110, 174, 365], 67: [12, 115, 125, 275], 68: [219, 346], 69: [149, 238, 297, 361], 70: [18, 180], 71: [68, 93, 310, 319], 72: [93, 156, 178], 73: [330], 74: [250, 334], 75: [11, 233], 76: [222, 274, 345], 77: [136], 78: [97, 175], 80: [326], 81: [20, 67, 97], 82: [81, 153, 332], 83: [55, 200, 297], 84: [303, 312], 85: [69, 139], 86: [249, 258], 87: [12, 116, 118], 88: [117], 89: [15, 20, 117, 311], 90: [21, 124, 248], 91: [8, 96, 132, 171, 220], 92: [25, 116, 281], 93: [30], 94: [142, 318], 95: [104, 112, 164, 166, 241], 96: [1, 46, 62, 334], 97: [189, 233], 98: [168, 302], 99: [71, 183, 329], 101: [96, 200, 242, 313], 102: [124, 288], 103: [52, 83, 306], 104: [360], 105: [194, 295], 106: [160, 226, 327], 107: [274, 332], 108: [9, 48, 58, 60], 109: [227, 254, 329], 110: [242, 275], 112: [294, 305, 356], 113: [32, 84, 126, 144], 114: [219], 115: [41, 298, 356], 116: [41, 283, 319], 117: [91, 259], 118: [59, 271, 314], 119: [197, 256], 120: [81], 121: [249, 355], 122: [55, 105, 307], 123: [293], 124: [46, 49, 163, 254], 125: [37, 157, 216, 239, 303], 127: [88, 121], 128: [26, 95, 243], 129: [141, 178], 130: [217, 275, 281, 304], 131: [66, 115, 120, 352], 132: [64, 98], 133: [185, 311, 365], 134: [42], 135: [255, 304], 137: [121, 271], 138: [230, 256, 340], 139: [13, 110, 120, 186], 140: [33, 275, 285], 141: [130], 142: [151, 254, 305, 358], 143: [91, 271], 144: [84, 282], 145: [110, 241, 339, 352], 146: [204], 147: [288], 148: [9, 283, 352], 149: [204, 251, 276], 150: [24, 138], 151: [194, 322, 339, 357], 152: [73, 112, 331], 153: [267], 154: [143, 169, 227], 155: [45, 130], 156: [24, 25, 68, 233, 278, 311, 326], 157: [232], 158: [7, 288], 159: [31, 333], 160: [26, 180], 161: [143, 186, 221], 163: [41, 133, 151, 238, 288, 304, 349], 164: [58, 66], 165: [161, 225], 166: [254, 303], 167: [13, 30, 81, 99, 249, 271], 168: [96, 118, 282, 363], 169: [18, 113], 170: [127, 247, 361], 171: [64, 132], 172: [133, 188, 226], 174: [41, 181, 332], 175: [32, 175, 246], 176: [48, 62, 195, 218, 240], 177: [164, 279], 178: [2, 153, 290], 179: [62, 161, 306, 327], 180: [241], 181: [118, 198, 215], 182: [335, 341], 183: [315, 357], 184: [45], 185: [293], 186: [32, 58], 187: [46, 54, 176], 188: [21, 157], 189: [10, 238, 352, 362], 192: [75, 80, 242], 194: [168], 195: [149], 196: [36, 160, 333, 334], 197: [69, 317], 198: [32, 57, 64, 86, 136, 230], 199: [94, 212], 200: [196], 201: [103, 235], 202: [106, 108, 184, 239, 321], 203: [211, 224], 204: [85, 205], 205: [95, 353], 206: [71, 336], 207: [88, 143, 308, 362], 208: [32, 177, 229], 209: [116, 243], 210: [51], 211: [50, 66, 239], 212: [12, 47, 289], 214: [65], 215: [35, 74], 216: [107, 164], 217: [51, 77, 109, 149, 195, 253], 219: [133, 138, 349], 220: [64, 143, 155, 195, 299], 221: [23 ...

# %% [markdown]
# Given a set of 45 students and after 1000 iterations, the probability of at least one match is 93.8%. This value is in line with the expected theoretical probability given the same number of students which is 93.4%. See probability_calc below.

# %%
#Compare results of bday_paradox with probability_calc.

def probability_calc(n):
    '''Returns a theoretical calculation of the probability that at least two people in a set of n number of people have the same birthday. '''
    exp = (n*(n-1))/2
    P = (1 - ((364/365)**exp)) * 100
    probability = print((round(P, 1)),'%')
    return probability

# %%
probability_calc(45)
# Out:
# 93.4 %
